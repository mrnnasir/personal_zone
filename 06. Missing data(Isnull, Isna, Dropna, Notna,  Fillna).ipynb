# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(seed=2)
np.random.choice([1,2,3], size=7)
# Out:
# array([1, 2, 1, 3, 3, 1, 3])

# %%
np.random.seed(seed=1)
df = pd.DataFrame(data={'A':np.random.choice([1,2,3,np.nan], size=3),
                        'B':np.random.choice([1,np.nan], size=3),
                        'C':np.random.choice([10,20], size=3)
                        })
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
# Simplest way to check for missing data levels in the tabular data

df.isnull().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df_practice = pd.read_csv('/Users/raihannasir/Documents/Pandas/New Materials/UKMacroData.csv')
df_practice
# Out:
#        Date  GDP (£ m)  CPI  Bank Rate  \
# 0   2000 Q1     401242  1.1      5.875
# 1   2000 Q2     404196  1.0      6.000
# 2   2000 Q3     406795  1.2      6.000
# 3   2000 Q4     409411  1.4      6.000
# 4   2001 Q1     413054  1.3      5.750
# ..      ...        ...  ...        ...
# 91  2022 Q4     568034  9.4      3.250
# 92  2023 Q1     569336  9.0      4.125
# 93  2023 Q2     569364  7.7      4.750
# 94  2023 Q3     568655  6.3      5.250
# 95  2023 Q4     566695  4.4      5.250
#
#     Gross Fixed Capital Formation (Investments)
# 0                                       69114.0
# 1                                       73074.0
# 2                                       68011.0
# 3                                       70115.0
# 4                                       70186.0
# ..                                          ...
# 91                                     106689.0
# 92                                     109290.0
# 93                                     108245.0
# 94                                     106496.0
# 95                                          NaN
#
# [96 rows x 5 columns]

# %%
df_practice.isnull().sum()
# Out:
# Date                                           0
# GDP (£ m)                                      0
# CPI                                            0
# Bank Rate                                      0
# Gross Fixed Capital Formation (Investments)    1
# dtype: int64

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
# DataFrame.dropna(*, axis=0, how=<no_default>, thresh=<no_default>, subset=None, inplace=False, ignore_index=False)
# .dropna() - it drops all rows that have missing data
# Notna needs to be used to save DataFrame without NA values. Dropna won't work.

df.dropna()
# Out:
#      A    B   C
# 0  2.0  1.0  20

# %%
# To remove column containing NA value using .dropna()

df.dropna(axis = 1)
# Out:
#     C
# 0  20
# 1  20
# 2  20

# %%
# Using Thresh parameter of .dropna(), row or column can be dropped

df.dropna(thresh=2) # thresh = 2 means, if row or column has 2 NA value will be dropped
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 2  1.0  NaN  20

# %%
# Define in which columns to look for missing values.

df.dropna(subset=['A','B'])
# Out:
#      A    B   C
# 0  2.0  1.0  20

# %%
df.dropna(subset=['A'])
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 2  1.0  NaN  20

# %%
# DataFrame.fillna(value=None, *, method=None, axis=None, inplace=False, limit=None, downcast=<no_default>)
# method{‘backfill’, ‘bfill’, ‘ffill’, None}, default None
# axis{0 or ‘index’} for Series, {0 or ‘index’, 1 or ‘columns’} for DataFrame

df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.fillna(value='Constant')
# Out:
#           A         B   C
# 0       2.0       1.0  20
# 1  Constant  Constant  20
# 2       1.0  Constant  20

# %%
df.fillna(value='Constant').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      object
#  1   B       3 non-null      object
#  2   C       3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.fillna(value=4)
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  4.0  4.0  20
# 2  1.0  4.0  20

# %%
# Inserting mean() value of Column A to NaN

df['A'].fillna(value=df['A'].mean(), inplace=True)
df
# Out:
# /var/folders/2h/2zcs8h612kxcwf4_nb9dj5dm0000gn/T/ipykernel_19684/902495023.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value=df['A'].mean(), inplace=True)
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df['A'].mean()
# Out:
# 1.5

# %%
df.fillna(method='ffill', axis=0)
# Out:
# /var/folders/2h/2zcs8h612kxcwf4_nb9dj5dm0000gn/T/ipykernel_19684/3122255136.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=0)
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  1.0  20
# 2  1.0  1.0  20

# %%
df['A'].fillna(method='ffill', axis=0, inplace=True)
df
# Out:
# /var/folders/2h/2zcs8h612kxcwf4_nb9dj5dm0000gn/T/ipykernel_19684/1438813948.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(method='ffill', axis=0, inplace=True)
# /var/folders/2h/2zcs8h612kxcwf4_nb9dj5dm0000gn/T/ipykernel_19684/1438813948.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['A'].fillna(method='ffill', axis=0, inplace=True)
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df.fillna(method='bfill')
# Out:
# /var/folders/2h/2zcs8h612kxcwf4_nb9dj5dm0000gn/T/ipykernel_19684/2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df1 = pd.read_csv('/Users/raihannasir/Documents/Pandas/New Materials/insurance.csv')
df1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isna().any(axis=0)
# Out:
# A    False
# B     True
# C    False
# dtype: bool

# %%
df2 = pd.read_csv('Fraud Detection Dataset.csv')
df2
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# 1                     13.0      Mobile       New York
# 2                      NaN      Mobile            NaN
# 3                     15.0     Desktop        Chicago
# 4                     19.0      Mobile  San Francisco
# ...                    ...         ...            ...
# 50995                 15.0      Mobile       New York
# 50996                  3.0      Mobile          Miami
# 50997                 18.0      Mobile  San Francisco
# 50998                 19.0      Tablet       New York
# 50999                  3.0      Tablet    Los Angeles
#
#        Previous_Fraudulent_Transactions  Account_Age  \
# 0                                     0          119
# 1                                     4           79
# 2                                     3          115
# 3                                     4            3
# 4                                     2           57
# ...                                 ...          ...
# 50995                                 0            7
# 50996                                 1           75
# 50997                                 3           73
# 50998                                 2          108
# 50999                                 0           50
#
#        Number_of_Transactions_Last_24H  Payment_Method  Fraudulent
# 0                                   13      Debit Card           0
# 1                                    3     Credit Card           0
# 2                                    9             NaN           0
# 3                                    4             UPI           0
# 4                                    7     Credit Card           0
# ...                                ...             ...         ...
# 50995                                8      Debit Card           0
# 50996                               11     Net Banking           1
# 50997                                5     Credit Card           0
# 50998                               14     Net Banking           0
# 50999                               10  Invalid Method           0
#
# [51000 rows x 12 columns]

# %%
df2['Location'].dtype
# Out:
# dtype('O')

# %%
def fillup(cell):
    if cell == 'NaN':
        return 'Unknown'
    else:
        return cell

df2['Location'] = df2['Location'].apply(fillup)
df2
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# 1                     13.0      Mobile       New York
# 2                      NaN      Mobile            NaN
# 3                     15.0     Desktop        Chicago
# 4                     19.0      Mobile  San Francisco
# ...                    ...         ...            ...
# 50995                 15.0      Mobile       New York
# 50996                  3.0      Mobile          Miami
# 50997                 18.0      Mobile  San Francisco
# 50998                 19.0      Tablet       New York
# 50999                  3.0      Tablet    Los Angeles
#
#        Previous_Fraudulent_Transactions  Account_Age  \
# 0                                     0          119
# 1                                     4           79
# 2                                     3          115
# 3                                     4            3
# 4                                     2           57
# ...                                 ...          ...
# 50995                                 0            7
# 50996                                 1           75
# 50997                                 3           73
# 50998                                 2          108
# 50999                                 0           50
#
#        Number_of_Transactions_Last_24H  Payment_Method  Fraudulent
# 0                                   13      Debit Card           0
# 1                                    3     Credit Card           0
# 2                                    9             NaN           0
# 3                                    4             UPI           0
# 4                                    7     Credit Card           0
# ...                                ...             ...         ...
# 50995                                8      Debit Card           0
# 50996                               11     Net Banking           1
# 50997                                5     Credit Card           0
# 50998                               14     Net Banking           0
# 50999                               10  Invalid Method           0
#
# [51000 rows x 12 columns]

# %%
def fillup(cell):
    if cell is np.nan:
        return 'Unknown'
    else:
        return cell

df2['Location'] = df2['Location'].apply(fillup)
df2
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# 1                     13.0      Mobile       New York
# 2                      NaN      Mobile        Unknown
# 3                     15.0     Desktop        Chicago
# 4                     19.0      Mobile  San Francisco
# ...                    ...         ...            ...
# 50995                 15.0      Mobile       New York
# 50996                  3.0      Mobile          Miami
# 50997                 18.0      Mobile  San Francisco
# 50998                 19.0      Tablet       New York
# 50999                  3.0      Tablet    Los Angeles
#
#        Previous_Fraudulent_Transactions  Account_Age  \
# 0                                     0          119
# 1                                     4           79
# 2                                     3          115
# 3                                     4            3
# 4                                     2           57
# ...                                 ...          ...
# 50995                                 0            7
# 50996                                 1           75
# 50997                                 3           73
# 50998                                 2          108
# 50999                                 0           50
#
#        Number_of_Transactions_Last_24H  Payment_Method  Fraudulent
# 0                                   13      Debit Card           0
# 1                                    3     Credit Card           0
# 2                                    9             NaN           0
# 3                                    4             UPI           0
# 4                                    7     Credit Card           0
# ...                                ...             ...         ...
# 50995                                8      Debit Card           0
# 50996                               11     Net Banking           1
# 50997                                5     Credit Card           0
# 50998                               14     Net Banking           0
# 50999                               10  Invalid Method           0
#
# [51000 rows x 12 columns]
